# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
import numpy as np
from tensorflow.keras.utils import to_categorical

#Cargar los datos de MNIST
#Aqui lo hago de otra manera porque es mas simple para poder usar el modulo de aumento de datos
#de Keras de esta manera
(X_entrenamiento, Y_entrenamiento), (X_pruebas, Y_pruebas) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 1s 0us/step

# %%
#Colocar los datos en la forma correcta que ya hemos visto (1, 28, 28, 1)
X_entrenamiento = X_entrenamiento.reshape(X_entrenamiento.shape[0], 28, 28, 1)
X_pruebas = X_pruebas.reshape(X_pruebas.shape[0], 28, 28, 1)

#Hacer 'one-hot encoding' de los resultados (e.g. en lugar de tener
#como resultado una sola neurona, tendre 10 donde solo el resultado correcto sera 1 y el resto 0)
Y_entrenamiento = to_categorical(Y_entrenamiento)
Y_pruebas = to_categorical(Y_pruebas)

#Convertir a flotante y normalizar para que aprenda mejor la red
X_entrenamiento = X_entrenamiento.astype('float32') / 255
X_pruebas = X_pruebas.astype('float32') / 255

# %%
#Codigo para mostrar imagenes del set, no es necesario ejecutarlo, solo imprime unos numeros :)
import matplotlib.pyplot as plt
filas = 2
columnas = 8
num = filas*columnas
imagenes = X_entrenamiento[0:num]
etiquetas = Y_entrenamiento[0:num]
fig, axes = plt.subplots(filas, columnas, figsize=(1.5*columnas,2*filas))
for i in range(num):
     ax = axes[i//columnas, i%columnas]
     ax.imshow(imagenes[i].reshape(28,28), cmap='gray_r')
     ax.set_title('Label: {}'.format(np.argmax(etiquetas[i])))
plt.tight_layout()
plt.show()

# %%
#Aumento de datos
#Variables para controlar las transformaciones que se haran en el aumento de datos
#utilizando ImageDataGenerator de keras

from tensorflow.keras.preprocessing.image import ImageDataGenerator

rango_rotacion = 30
mov_ancho = 0.25
mov_alto = 0.25
#rango_inclinacion=15 #No uso este de momento pero si quieres puedes probar usandolo!
rango_acercamiento=[0.5,1.5]

datagen = ImageDataGenerator(
    rotation_range = rango_rotacion,
    width_shift_range = mov_ancho,
    height_shift_range = mov_alto,
    zoom_range=rango_acercamiento,
    #shear_range=rango_inclinacion #No uso este de momento pero si quieres puedes probar usandolo!
)

datagen.fit(X_entrenamiento)

# %%
#Codigo para mostrar imagenes del set, no es necesario ejecutarlo, solo imprime como se ven antes y despues de las transformaciones
filas = 4
columnas = 8
num = filas*columnas
print('ANTES:\n')
fig1, axes1 = plt.subplots(filas, columnas, figsize=(1.5*columnas,2*filas))
for i in range(num):
     ax = axes1[i//columnas, i%columnas]
     ax.imshow(X_entrenamiento[i].reshape(28,28), cmap='gray_r')
     ax.set_title('Label: {}'.format(np.argmax(Y_entrenamiento[i])))
plt.tight_layout()
plt.show()
print('DESPUES:\n')
fig2, axes2 = plt.subplots(filas, columnas, figsize=(1.5*columnas,2*filas))
for X, Y in datagen.flow(X_entrenamiento,Y_entrenamiento.reshape(Y_entrenamiento.shape[0], 10),batch_size=num,shuffle=False):
     for i in range(0, num):
          ax = axes2[i//columnas, i%columnas]
          ax.imshow(X[i].reshape(28,28), cmap='gray_r')
          ax.set_title('Label: {}'.format(int(np.argmax(Y[i]))))
     break
plt.tight_layout()
plt.show()
# Out:
# ANTES:
# DESPUES:

# %%
#Modelo!
modelo = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(28, 28, 1)),
    tf.keras.layers.MaxPooling2D(2, 2),

    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dense(10, activation="softmax")
])

#Compilación
modelo.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
#Los datos para entrenar saldran del datagen, de manera que sean generados con las transformaciones que indicamos
data_gen_entrenamiento = datagen.flow(X_entrenamiento, Y_entrenamiento, batch_size=32)

# %%
TAMANO_LOTE = 32

#Entrenar la red. Toma un buen rato! Ve por un café ;)
#Oye suscribete al canal!
print("Entrenando modelo...");
epocas=60
history = modelo.fit(
    data_gen_entrenamiento,
    epochs=epocas,
    batch_size=TAMANO_LOTE,
    validation_data=(X_pruebas, Y_pruebas),
    steps_per_epoch=int(np.ceil(60000 / float(TAMANO_LOTE))),
    validation_steps=int(np.ceil(10000 / float(TAMANO_LOTE)))
)

print("Modelo entrenado!");
# Out:
# Entrenando modelo...
# Epoch 1/60
# 1875/1875 [==============================] - 34s 18ms/step - loss: 0.9479 - accuracy: 0.6905 - val_loss: 0.1604 - val_accuracy: 0.9576
# Epoch 2/60
# 1875/1875 [==============================] - 29s 16ms/step - loss: 0.6593 - accuracy: 0.7865 - val_loss: 0.1483 - val_accuracy: 0.9582
# Epoch 3/60
# 1875/1875 [==============================] - 29s 16ms/step - loss: 0.5693 - accuracy: 0.8165 - val_loss: 0.1218 - val_accuracy: 0.9632
# Epoch 4/60
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.5185 - accuracy: 0.8322 - val_loss: 0.1059 - val_accuracy: 0.9680
# Epoch 5/60
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.4856 - accuracy: 0.8427 - val_loss: 0.0991 - val_accuracy: 0.9687
# Epoch 6/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.4556 - accuracy: 0.8531 - val_loss: 0.0731 - val_accuracy: 0.9761
# Epoch 7/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.4413 - accuracy: 0.8571 - val_loss: 0.0647 - val_accuracy: 0.9802
# Epoch 8/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.4207 - accuracy: 0.8651 - val_loss: 0.0598 - val_accuracy: 0.9813
# Epoch 9/60
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.4111 - accuracy: 0.8679 - val_loss: 0.0675 - val_accuracy: 0.9801
# Epoch 10/60
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.4005 - accuracy: 0.8717 - val_loss: 0.0604 - val_accuracy: 0.9803
# Epoch 11/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.3912 - accuracy: 0.8737 - val_loss: 0.0538 - val_accuracy: 0.9829
# Epoch 12/60
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.3829 - accuracy: 0.8746 - val_loss: 0.0626 - val_accuracy: 0.9796
# Epoch 13/60
# 1875/1875 [==============================] - 27s 15ms/step - loss: 0.3792 - accuracy: 0.8764 - val_loss: 0.0586 - val_accuracy: 0.9806
# Epoch 14/60
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.3631 - accuracy: 0.8830 - val_loss: 0.0485 - val_accuracy: 0.9838
# Epoch 15/60
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.3651 - accuracy: 0.8827 - val_loss: 0.0512 - val_accuracy: 0.9833
# Epoch 16/60
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.3621 - accuracy: 0.8816 - val_loss: 0.0786 - val_accuracy: 0.9750
# Epoch 17/60
# 1875/1875 [==============================] - 27s 15ms/step - loss: 0.3547 - accuracy: 0.8861 - val_loss: 0.0553 - val_accuracy: 0.9817
# Epoch 18/60
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.3490 - accuracy: 0.8882 - val_loss: 0.0599 - val_accuracy: 0.9805
# Epoch 19/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.3413 - accuracy: 0.8896 - val_loss: 0.0621 - val_accuracy: 0.9799
# Epoch 20/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.3373 - accuracy: 0.8906 - val_loss: 0.0611 - val_accuracy: 0.9790
# Epoch 21/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.3390 - accuracy: 0.8909 - val_loss: 0.0559 - val_accuracy: 0.9804
# Epoch 22/60
# 1875/1875 [==============================] - 27s 15ms/step - loss: 0.3325 - accuracy: 0.8914 - val_loss: 0.0561 - val_accuracy: 0.9833
# Epoch 23/60
# 1875/1875 [==============================] - 27s 15ms/step - loss: 0.3304 - accuracy: 0.8923 - val_loss: 0.0551 - val_accuracy: 0.9819
# Epoch 24/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.3321 - accuracy: 0.8925 - val_loss: 0.0493 - val_accuracy: 0.9838
# Epoch 25/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.3201 - accuracy: 0.8979 - val_loss: 0.0507 - val_accuracy: 0.9842
# Epoch 26/60
# 1875/1875 [==============================] - 27s 15ms/step - loss: 0.3238 - accuracy: 0.8960 - val_loss: 0.0513 - val_accuracy: 0.9843
# Epoch 27/60
# 1875/1875 [==============================] - 27s 15ms/step - loss: 0.3180 - accuracy: 0.8966 - val_loss: 0.0570 - val_accuracy: 0.9808
# Epoch 28/60
# 1875/1875 [==============================] - 27s 15ms/step - loss: 0.3178 - accuracy: 0.8978 - val_loss: 0.0526 - val_accuracy: 0.9827
# Epoch 29/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.3222 - accuracy: 0.8958 - val_loss: 0.0455 - val_accuracy: 0.9853
# Epoch 30/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.3169 - accuracy: 0.8979 - val_loss: 0.0489 - val_accuracy: 0.9838
# Epoch 31/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.3110 - accuracy: 0.8990 - val_loss: 0.0541 - val_accuracy: 0.9830
# Epoch 32/60
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.3032 - accuracy: 0.9018 - val_loss: 0.0519 - val_accuracy: 0.9831
# Epoch 33/60
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.3117 - accuracy: 0.8994 - val_loss: 0.0496 - val_accuracy: 0.9832
# Epoch 34/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.3066 - accuracy: 0.9010 - val_loss: 0.0523 - val_accuracy: 0.9836
# Epoch 35/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.3111 - accuracy: 0.8993 - val_loss: 0.0425 - val_accuracy: 0.9856
# Epoch 36/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.3065 - accuracy: 0.9010 - val_loss: 0.0455 - val_accuracy: 0.9859
# Epoch 37/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.3053 - accuracy: 0.9021 - val_loss: 0.0454 - val_accuracy: 0.9843
# Epoch 38/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.3074 - accuracy: 0.8991 - val_loss: 0.0632 - val_accuracy: 0.9802
# Epoch 39/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.3007 - accuracy: 0.9023 - val_loss: 0.0471 - val_accuracy: 0.9845
# Epoch 40/60
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.2991 - accuracy: 0.9035 - val_loss: 0.0580 - val_accuracy: 0.9811
# Epoch 41/60
# 1875/1875 [==============================] - 27s 15ms/step - loss: 0.2998 - accuracy: 0.9041 - val_loss: 0.0482 - val_accuracy: 0.9847
# Epoch 42/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.2975 - accuracy: 0.9034 - val_loss: 0.0433 - val_accuracy: 0.9863
# Epoch 43/60
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.2900 - accuracy: 0.9059 - val_loss: 0.0541 - val_accuracy: 0.9828
# Epoch 44/60
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.2933 - accuracy: 0.9054 - val_loss: 0.0523 - val_accuracy: 0.9830
# Epoch 45/60
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.2963 - accuracy: 0.9047 - val_loss: 0.0414 - val_accuracy: 0.9874
# Epoch 46/60
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.2920 - accuracy: 0.9055 - val_loss: 0.0587 - val_accuracy: 0.9816
# Epoch 47/60
# 1875/1875 [==============================] - 27s 15ms/step - loss: 0.2903 - accuracy: 0.9067 - val_loss: 0.0438 - val_accuracy: 0.9862
# Epoch 48/60
# 1875/1875 [==============================] - 27s 15ms/step - loss: 0.2897 - accuracy: 0.9073 - val_loss: 0.0489 - val_accuracy: 0.9846
# Epoch 49/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.2874 - accuracy: 0.9068 - val_loss: 0.0501 - val_accuracy: 0.9820
# Epoch 50/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.2826 - accuracy: 0.9082 - val_loss: 0.0437 - val_accuracy: 0.9868
# Epoch 51/60
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.2887 - accuracy: 0.9065 - val_loss: 0.0602 - val_accuracy: 0.9812
# Epoch 52/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.2880 - accuracy: 0.9071 - val_loss: 0.0502 - val_accuracy: 0.9841
# Epoch 53/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.2814 - accuracy: 0.9094 - val_loss: 0.0587 - val_accuracy: 0.9815
# Epoch 54/60
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.2859 - accuracy: 0.9072 - val_loss: 0.0419 - val_accuracy: 0.9864
# Epoch 55/60
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.2874 - accuracy: 0.9066 - val_loss: 0.0512 - val_accuracy: 0.9836
# Epoch 56/60
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.2870 - accuracy: 0.9080 - val_loss: 0.0576 - val_accuracy: 0.9808
# Epoch 57/60
# 1875/1875 [==============================] - 29s 15ms/step - loss: 0.2811 - accuracy: 0.9109 - val_loss: 0.0520 - val_accuracy: 0.9822
# Epoch 58/60
# 1875/1875 [==============================] - 27s 15ms/step - loss: 0.2806 - accuracy: 0.9095 - val_loss: 0.0475 - val_accuracy: 0.9857
# Epoch 59/60
# 1875/1875 [==============================] - 27s 15ms/step - loss: 0.2803 - accuracy: 0.9093 - val_loss: 0.0615 - val_accuracy: 0.9796
# Epoch 60/60
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.2842 - accuracy: 0.9081 - val_loss: 0.0592 - val_accuracy: 0.9819
# Modelo entrenado!
